# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from Methods.SBM import SBM

models_params = {
    "anvits_model": {
        "args" : {
            "n_clusters": 4,
            "scale_embedding": True,
            "n_vectors": -1,
            "dtype": "main",
            "eigen_val_weight": 1/4,
        }
    },
    "spectral_clustering": {
        "args": {
            "n_clusters": 4,
            "scale_embedding": False,
            "n_vectors": 3,
            "dtype": "main",
        }
    },
}

for model_name in models_params:
    model = SBM(**models_params[model_name]["args"]).fit()
    models_params[model_name]["model"] = model

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
curr = "anvits_model"


models_params[curr]["model"].plot_embedding(ax = ax[0])
models_params[curr]["model"].plot_map(ax = ax[1])
# Out:
# <Axes: >
